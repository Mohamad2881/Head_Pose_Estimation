# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error

import pickle

# %% [markdown]
# ## Load Data

# %%
df_normalized = pd.read_csv('./Data/Data_normalized.csv')
df_normalized
# Out:
#         img_name        x1        y1   x2   y2        x3        y3        x4  \
# 0     image00002 -0.021071  0.280501  0.0  0.0  0.003618  0.044809 -0.056280
# 1     image00004  0.152873  0.314467  0.0  0.0  0.199169  0.115431  0.118121
# 2     image00008  0.205183  0.240938  0.0  0.0  0.119186  0.028852 -0.149639
# 3     image00013  0.090869  0.333388  0.0  0.0  0.036468  0.102085 -0.131615
# 4     image00014  0.040906  0.353475  0.0  0.0  0.032162  0.121086 -0.064759
# ...          ...       ...       ...  ...  ...       ...       ...       ...
# 1830  image04345 -0.119273  0.398858  0.0  0.0 -0.096150  0.096688 -0.145282
# 1831  image04348 -0.135242  0.345140  0.0  0.0 -0.101198  0.073061 -0.124628
# 1832  image04356 -0.105000  0.305106  0.0  0.0 -0.061799  0.105663 -0.008501
# 1833  image04358 -0.055918  0.343104  0.0  0.0 -0.020752  0.075734 -0.065553
# 1834  image04375  0.010317  0.355314  0.0  0.0 -0.004551  0.120091 -0.095907
#
# ...

# %%
X = df_normalized.iloc[:, 1:-3]
y = df_normalized.iloc[:, -3:]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, shuffle=True)

# %%
# save the model to disk
model_path = 'Saved models/model_MultiOutput.pkl'
pickle.dump(model, open(model_path, 'wb'))

# %% [markdown]
# # Pitch

# %%
model_pitch = SVR(C=100, kernel='poly')
model_pitch.fit(x_train, y_train['pitch'])

print("Train Error: ",mean_absolute_error(model_pitch.predict(x_train), y_train['pitch']))
print("Validation Error: ",mean_absolute_error(model_pitch.predict(x_test),y_test['pitch']))
# Out:
# Train Error:  0.09665287977868164
# Validation Error:  0.09085894153346756

# %% [markdown]
# # Yaw

# %%
model_yaw = SVR(C=100, kernel='poly')
model_yaw.fit(x_train, y_train['yaw'])

print("Train Error: ",mean_absolute_error(model_yaw.predict(x_train), y_train['yaw']))
print("Validation Error: ",mean_absolute_error(model_yaw.predict(x_test), y_test['yaw']))
# Out:
# Train Error:  0.0689447939432711
# Validation Error:  0.07504833333875832

# %% [markdown]
# # Roll

# %%
model_roll = SVR(C=100, kernel='poly')
model_roll.fit(x_train, y_train['roll'])

print("Train Error: ", mean_absolute_error(model_roll.predict(x_train), y_train['roll']))
print("Validation Error: ", mean_absolute_error(model_roll.predict(x_test), y_test['roll']))
# Out:
# Train Error:  0.08194576779262645
# Validation Error:  0.07097259634588743

# %% [markdown]
# # Save Models to disk

# %%
model_name = 'Saved models/model_pitch.pkl'
pickle.dump(model_pitch, open(model_name, 'wb'))

model_name = 'Saved models/model_yaw.pkl'
pickle.dump(model_yaw, open(model_name, 'wb'))
 
model_name = 'Saved models/model_roll.pkl'
pickle.dump(model_roll, open(model_name, 'wb'))
